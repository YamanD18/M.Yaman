# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

bulan = ['Januari','Februari','Maret','April','Mei','Juni','Juli','Agustus','September','Oktober','November','Desember']

#pengeluaran antara 500.000 - 2.000.000

Minggu_1 = np.random.randint(500000,2000001,12)
Minggu_2 = np.random.randint(500000,2000001,12)
Minggu_3 = np.random.randint(500000,2000001,12)
Minggu_4 = np.random.randint(500000,2000001,12)

data ={
    'Bulan' : bulan,
    'Minggu_1' : Minggu_1,
    'Minggu_2' : Minggu_2,
    'Minggu_3' : Minggu_3,
    'Minggu_4' : Minggu_4,
}
df = pd.DataFrame(data)

df['total_pengeluaran'] = df[['Minggu_1','Minggu_2','Minggu_3','Minggu_4']].sum(axis=1)
df
# Out:
#         Bulan  Minggu_1  Minggu_2  Minggu_3  Minggu_4  total_pengeluaran
# 0     Januari   1142285    967143   1358943   1012085            4480456
# 1    Februari    647736   1909470   1683089    915848            5156143
# 2       Maret   1298586    702813    551187    865746            3418332
# 3       April    735905   1821800   1631280    670656            4859641
# 4         Mei   1673055   1469980    660361   1221225            5024621
# 5        Juni    604115   1891045   1261901   1005059            4762120
# 6        Juli   1022247   1108799   1055243   1927777            5114066
# 7     Agustus   1083593    502966   1852892   1759222            5198673
# 8   September   1166328   1575103   1983065   1805847            6530343
# 9     Oktober   1100379   1293882   1645404   1965082            6004747
# 10   November   1864065    789492   1045693   1141322            4840572
# 11   Desember   1823162    714805   1957051    509215            5004233

# %%
plt.figure(figsize=(12,6)) #Canvas dengan ukuran width,heigth (inch)
plt.title('Total Pengeluaran per Bulan')
plt.bar(df['Bulan'],df['total_pengeluaran'], color='orange')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.ylabel("Rupiah")
plt.show()

# %%
#Scatter plot untuk analisa data pengeluaran per minggu per bulan
plt.figure(figsize=(12,6))
for minggu in ['Minggu_1','Minggu_2','Minggu_3','Minggu_4']:
    plt.plot(df['Bulan'],df[minggu] ,marker='o',label=minggu)

plt.title("Pengeluaran per Minggu")
plt.xlabel('Bulan')
plt.ylabel('Pengeluaran (Rupiah)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
#Pie Chart --> persentase
plt.figure(figsize=(10,10))
plt.pie(df['total_pengeluaran'],labels=df['Bulan'],startangle=90,autopct='%1.1f%%')
plt.tight_layout()
plt.axis('equal')
plt.show()

# %%
from sklearn.linear_model import LinearRegression

df['Bulan_Angka'] = np.arange(1,13)

x = df[['Bulan_Angka']]
y = df['total_pengeluaran']

model = LinearRegression()

model.fit(x,y)

prediksi = model.predict([[13]])[0]
print(f"Hasil prediksi adalah: {prediksi:,.0f}")
# Out:
# Hasil prediksi adalah: 5,720,418
# C:\Users\yaman\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
df = pd.read_csv('datakecminim.csv')
df
# Out:
#                DIAJUKAN_DI                     KAB_KOTA  \
# 0          PERWAKILAN PATI                         PATI
# 1      PERWAKILAN MAGELANG                     WONOSOBO
# 2      PERWAKILAN MAGELANG                     WONOSOBO
# 3      PERWAKILAN MAGELANG                     WONOSOBO
# 4      PERWAKILAN MAGELANG                   TEMANGGUNG
# ...                    ...                          ...
# 36050      PERWAKILAN PATI                        BLORA
# 36051          KPJR KLATEN                       KLATEN
# 36052          KPJR WANGON    SATLANTAS METRO JAK BARAT
# 36053           KPJR DEMAK               KOTA  SEMARANG
# 36054           KPJR TEGAL  SATLANTAS METRO JAK SELATAN
#
#                          KECAMATAN KODE_CIDERA           PROFESI  TANGGAL  \
# 0                             PATI          LL        WIRASWASTA        2
# 1                         WONOSOBO          MD        WIRASWASTA        7
# 2                         WONOSOBO          LL        WIRASWASTA        7
# 3                         WONOSOBO          MD         TNI POLRI       20
# 4                       TEMANGGUNG          MD        WIRASWASTA       24
# ...                            ...         ...               ...      ...
# 36050                        BLORA          LL      BURUH PETANI       11
# 36051                       KLATEN          LL  IBU RUMAH TANGGA       12
# 36052    SATLANTAS METRO JAK BARAT          MD      BURUH PETANI       29
# 36053               KOTA  SEMARANG          LL        WIRASWASTA        6
# 36054  SATLANTAS METRO JAK SELATAN          MD         LAIN LAIN       27
#
#        BULAN  TAHUN    JAM       KARAKTERISTIK LAKA
# 0          1   2023   6:30           BERUNTUN/GANDA
# 1          1   2023  21:00              DEPAN-DEPAN
# 2          1   2023  21:00  PEJALAN-KAKI/SEJENISNYA
# 3          1   2023   5:00            DEPAN-SAMPING
# 4          1   2023   2:30              DEPAN-DEPAN
# ...      ...    ...    ...                      ...
# 36050      4   2024  14:30              DEPAN-DEPAN
# 36051      4   2024  10:00            DEPAN-SAMPING
# 36052      4   2024   3:12           DEPAN-BELAKANG
# 36053      4   2024  11:30          SAMPING-SAMPING
# 36054      4   2024   4:10  PEJALAN-KAKI/SEJENISNYA
#
# [36055 rows x 10 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('datakecminim.csv')
df

#dengan data ini kita bisa melihat seberapa banyak laka yang terjadi di indonesia
# Out:
#                DIAJUKAN_DI                     KAB_KOTA  \
# 0          PERWAKILAN PATI                         PATI
# 1      PERWAKILAN MAGELANG                     WONOSOBO
# 2      PERWAKILAN MAGELANG                     WONOSOBO
# 3      PERWAKILAN MAGELANG                     WONOSOBO
# 4      PERWAKILAN MAGELANG                   TEMANGGUNG
# ...                    ...                          ...
# 36050      PERWAKILAN PATI                        BLORA
# 36051          KPJR KLATEN                       KLATEN
# 36052          KPJR WANGON    SATLANTAS METRO JAK BARAT
# 36053           KPJR DEMAK               KOTA  SEMARANG
# 36054           KPJR TEGAL  SATLANTAS METRO JAK SELATAN
#
#                          KECAMATAN KODE_CIDERA           PROFESI  TANGGAL  \
# 0                             PATI          LL        WIRASWASTA        2
# 1                         WONOSOBO          MD        WIRASWASTA        7
# 2                         WONOSOBO          LL        WIRASWASTA        7
# 3                         WONOSOBO          MD         TNI POLRI       20
# 4                       TEMANGGUNG          MD        WIRASWASTA       24
# ...                            ...         ...               ...      ...
# 36050                        BLORA          LL      BURUH PETANI       11
# 36051                       KLATEN          LL  IBU RUMAH TANGGA       12
# 36052    SATLANTAS METRO JAK BARAT          MD      BURUH PETANI       29
# 36053               KOTA  SEMARANG          LL        WIRASWASTA        6
# 36054  SATLANTAS METRO JAK SELATAN          MD         LAIN LAIN       27
#
#        BULAN  TAHUN    JAM       KARAKTERISTIK LAKA
# 0          1   2023   6:30           BERUNTUN/GANDA
# 1          1   2023  21:00              DEPAN-DEPAN
# 2          1   2023  21:00  PEJALAN-KAKI/SEJENISNYA
# 3          1   2023   5:00            DEPAN-SAMPING
# 4          1   2023   2:30              DEPAN-DEPAN
# ...      ...    ...    ...                      ...
# 36050      4   2024  14:30              DEPAN-DEPAN
# 36051      4   2024  10:00            DEPAN-SAMPING
# 36052      4   2024   3:12           DEPAN-BELAKANG
# 36053      4   2024  11:30          SAMPING-SAMPING
# 36054      4   2024   4:10  PEJALAN-KAKI/SEJENISNYA
#
# [36055 rows x 10 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('jmlh_kclkn_prkrn_krgn_mtr_stp_bln_d_kbptn_knngn.csv')
df

#Data kecelakaaan kabupaten Kuningan di tahun 2023
#Mayoritas bulan dalam tahun 2023 bebas dari kecelakaan.
#Mei dan Oktober adalah satu-satunya bulan dengan kecelakaan, 
#Total kerugian materiil selama tahun 2023:
#Rp40.000.000 dari total 3 kecelakaan
#Rata-rata kerugian per kecelakaan adalah Rp13.333.333
#Meskipun kecelakaan sedikit, kerugiannya cukup signifikan.
#Perlu dipertimbangkan upaya pencegahan pada bulan-bulan rawan seperti Mei dan Oktober.
#Kabupaten Kuningan menunjukkan tingkat kecelakaan yang sangat rendah di 2023.
#Fokus pencegahan dapat diarahkan pada bulan-bulan rawan (Mei & Oktober).
# Out:
#     id  kode_provinsi nama_provinsi  bps_kode_kabupaten_kota  \
# 0    1             32    JAWA BARAT                     3208
# 1    2             32    JAWA BARAT                     3208
# 2    3             32    JAWA BARAT                     3208
# 3    4             32    JAWA BARAT                     3208
# 4    5             32    JAWA BARAT                     3208
# 5    6             32    JAWA BARAT                     3208
# 6    7             32    JAWA BARAT                     3208
# 7    8             32    JAWA BARAT                     3208
# 8    9             32    JAWA BARAT                     3208
# 9   10             32    JAWA BARAT                     3208
# 10  11             32    JAWA BARAT                     3208
# 11  12             32    JAWA BARAT                     3208
#
#    bps_nama_kabupaten_kota      bulan  jumlah_kecelakaan  \
# 0       KABUPATEN KUNINGAN    JANUARI                  0
# 1       KABUPATEN KUNINGAN   FEBRUARI                  0
# 2       KABUPATEN KUNINGAN      MARET                  0
# 3       KABUPATEN KUNINGAN      APRIL                  0
# 4       KABUPATEN KUNINGAN        MEI                  2
# 5       KABUPATEN KUNINGAN       JUNI                  0
# 6       KABUPATEN KUNINGAN       JULI                  0
# 7       KABUPATEN KUNINGAN    AGUSTUS                  0
# 8       KABUPATEN KUNINGAN  SEPTEMBER                  0
# 9       KABUPATEN KUNINGAN    OKTOBER                  1
# 10      KABUPATEN KUNINGAN   NOVEMBER                  0
# 11      KABUPATEN KUNINGAN   DESEMBER                  0
#
#     perkiraan_kerugian_materi  tahun
# 0                           0   2023
# 1                           0   2023
# 2                           0   2023
# 3                           0   2023
# 4                    30000000   2023
# 5                           0   2023
# 6                           0   2023
# 7                           0   2023
# 8                           0   2023
# 9                    10000000   2023
# 10                          0   2023
# 11                          0   2023
